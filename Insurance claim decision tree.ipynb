# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('insurance_claims.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
# Drop the null column
df=df.drop('_c39',axis=1)

# %%
# Drop Unwanted columns
df=df.drop(['policy_number','policy_bind_date','incident_date','incident_location','insured_zip'],axis=1)

# %%
df.isnull().sum()
# Out:
# months_as_customer              0
# age                             0
# policy_state                    0
# policy_csl                      0
# policy_deductable               0
# policy_annual_premium           0
# umbrella_limit                  0
# insured_sex                     0
# insured_education_level         0
# insured_occupation              0
# insured_hobbies                 0
# insured_relationship            0
# capital-gains                   0
# capital-loss                    0
# incident_type                   0
# collision_type                  0
# incident_severity               0
# authorities_contacted          91
# incident_state                  0
# incident_city                   0
# incident_hour_of_the_day        0
# number_of_vehicles_involved     0
# property_damage                 0
# bodily_injuries                 0
# witnesses                       0
# police_report_available         0
# total_claim_amount              0
# ...

# %%
# drop authorities_contacted which has his null values
df=df.drop('authorities_contacted', axis=True)

# %%
df.shape
# Out:
# (1000, 33)

# %%
# Keep only the necessary features and drp all the other features
df = df1.drop([
    'policy_number',
    'policy_bind_date',
    'incident_date',
    'incident_location',
    'insured_zip',
    'policy_annual_premium',
    'policy_csl',
    'policy_deductable',
    'policy_state',
    'umbrella_limit',
    'insured_hobbies',
    'insured_relationship',
    'insured_sex',
    'insured_education_level',
    'capital-loss',
    'age',
    'authorities_contacted',
    'incident_state',
    'incident_city',
    'auto_make',
    'auto_model',
    'auto_year',], axis=1)
print(df.shape)
# Out:
# (1000, 17)

# %%
df.head()
# Out:
#    months_as_customer insured_occupation  capital-gains  \
# 0                 328       craft-repair          53300
# 1                 228  machine-op-inspct              0
# 2                 134              sales          35100
# 3                 256       armed-forces          48900
# 4                 228              sales          66000
#
#               incident_type   collision_type incident_severity  \
# 0  Single Vehicle Collision   Side Collision      Major Damage
# 1             Vehicle Theft                ?      Minor Damage
# 2   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3  Single Vehicle Collision  Front Collision      Major Damage
# 4             Vehicle Theft                ?      Minor Damage
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# ...

# %%
import numpy as np

df = df.replace(['?', 'NaN', 'nan'], np.nan)

# %%
df
# Out:
#      months_as_customer insured_occupation  capital-gains  \
# 0                   328       craft-repair          53300
# 1                   228  machine-op-inspct              0
# 2                   134              sales          35100
# 3                   256       armed-forces          48900
# 4                   228              sales          66000
# ..                  ...                ...            ...
# 995                   3       craft-repair              0
# 996                 285     prof-specialty          70900
# 997                 130       armed-forces          35100
# 998                 458  handlers-cleaners              0
# 999                 456              sales              0
#
#                 incident_type   collision_type incident_severity  \
# 0    Single Vehicle Collision   Side Collision      Major Damage
# 1               Vehicle Theft              NaN      Minor Damage
# 2     Multi-vehicle Collision   Rear Collision      Minor Damage
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer               0
# insured_occupation               0
# capital-gains                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                360
# bodily_injuries                  0
# witnesses                        0
# police_report_available        343
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# fraud_reported                   0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# months_as_customer               0
# insured_occupation               0
# capital-gains                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                360
# bodily_injuries                  0
# witnesses                        0
# police_report_available        343
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# fraud_reported                   0
# dtype: int64

# %%
df.dtypes
# Out:
# months_as_customer              int64
# insured_occupation             object
# capital-gains                   int64
# incident_type                  object
# collision_type                 object
# incident_severity              object
# incident_hour_of_the_day        int64
# number_of_vehicles_involved     int64
# property_damage                object
# bodily_injuries                 int64
# witnesses                       int64
# police_report_available        object
# total_claim_amount              int64
# injury_claim                    int64
# property_claim                  int64
# vehicle_claim                   int64
# fraud_reported                 object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['insured_occupation']      = le.fit_transform(df['insured_occupation'])
df['incident_type']           = le.fit_transform(df['incident_type'])
df['incident_severity']       = le.fit_transform(df['incident_severity'])
df['fraud_reported']          = le.fit_transform(df['fraud_reported'])
df['property_damage']         = le.fit_transform(df['property_damage'])
df['police_report_available'] = le.fit_transform(df['police_report_available'])
df['collision_type']          = le.fit_transform(df['collision_type'])
print(df.dtypes)
print(df.shape)   # should still be (rows, 16) — no new columns
# Out:
# months_as_customer             int64
# insured_occupation             int64
# capital-gains                  int64
# incident_type                  int64
# collision_type                 int64
# incident_severity              int64
# incident_hour_of_the_day       int64
# number_of_vehicles_involved    int64
# property_damage                int64
# bodily_injuries                int64
# witnesses                      int64
# police_report_available        int64
# total_claim_amount             int64
# injury_claim                   int64
# property_claim                 int64
# vehicle_claim                  int64
# fraud_reported                 int64
# dtype: object
# (1000, 17)

# %%
col=df.columns[4:].tolist()
cols=df.columns.tolist()

# %%
col = df.columns.tolist()
plt.figure(figsize=(15,12))
for i in range(len(col)):
    plt.subplot(3,3,i+1)
    plt.hist(df[col[i]])
plt.title(col[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 4
#       2 plt.figure(figsize=(15,12))
#       3 for i in range(len(col)):
# ----> 4     plt.subplot(3,3,i+1)
#       5     plt.hist(df[col[i]])
#       6 plt.title(col[i])
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1550, in subplot(*args, **kwargs)
#    1547 fig = gcf()
#    1549 # First, search for an existing subplot with a matching spec.
# -> 1550 key = SubplotSpec._from_subplot_args(fig, args)
#    1552 for ax in fig.axes:
#    1553     # If we found an Axes at the position, we can reuse it if the user passed no
#    1554     # kwargs or if the Axes class and kwargs are identical.
#    1555     if (ax.get_subplotspec() == key
#    1556         and (kwargs == {}
#    1557              or (ax._projection_init
#    1558                  == fig._process_projection_requirements(**kwargs)))):
#
# ...

# %%
for i in range(len(cols)):
    plt.subplot(4,4,i+1)
    plt.boxplot(df[cols[i]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 2
#       1 for i in range(len(cols)):
# ----> 2     plt.subplot(4,4,i+1)
#       3     plt.boxplot(df[cols[i]])
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1550, in subplot(*args, **kwargs)
#    1547 fig = gcf()
#    1549 # First, search for an existing subplot with a matching spec.
# -> 1550 key = SubplotSpec._from_subplot_args(fig, args)
#    1552 for ax in fig.axes:
#    1553     # If we found an Axes at the position, we can reuse it if the user passed no
#    1554     # kwargs or if the Axes class and kwargs are identical.
#    1555     if (ax.get_subplotspec() == key
#    1556         and (kwargs == {}
#    1557              or (ax._projection_init
#    1558                  == fig._process_projection_requirements(**kwargs)))):
#
# ...

# %%
from scipy.stats.mstats import winsorize
df['vehicle_claim']=winsorize(df['vehicle_claim'] ,limits=[0.05,0.05])
df

# %%
plt.bar(df['vehicle_claim'],df['vehicle_claim'])
plt.ylabel("vehicle_claim after handling outlier")
plt.xlabel("Original vehicle_claim")
plt.show()

# %%
x=df.drop('fraud_reported',axis=1)
y=df['fraud_reported']

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)
d.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree
plt.figure(figsize=(150,100))
tree.plot_tree(d,filled=True, max_depth=3)
plt.show()

# %%
ypred=d.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report
print("Accuracy score :",accuracy_score(ytest,ypred))
# Out:
# Accuracy score : 0.73

# %%
print(confusion_matrix(ytest, ypred))
# Out:
# [[182  38]
#  [ 43  37]]

# %%
plt.plot(ytest,label="Actual")
plt.plot(ypred,label="Predicted")
plt.legend()
plt.title("Actual vs Predicted")
plt.show()

# %%
cm=confusion_matrix(ytest,ypred)
sns.heatmap(cm , annot=True, cmap='Blues') # annot is to dislay the values
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')
